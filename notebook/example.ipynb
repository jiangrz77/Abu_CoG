# %%
import os, sys
sys.path.append(os.path.relpath('../'))
from src.load_obs import Obs

# %%
# What do I need to intialize this program?
##0##  Source, identifiers or index is recommended if you get a long list of objects
##1##  Atmospheric Parameters: Teff, logg, microturbulence velocity vt, metallicity [Fe/H]
##2##  EW_X at AAAA wavelength
data = Obs('Example', overwrite=True)
# data = Obs('BENCHMARK', overwrite=True) ### BENCHMARK stars from original paper of Lind et al. 2022
# Setting overwrite=True forces recomputation and overwrites existing results; set overwrite=False to skip recomputation and use cached/saved results
# Set silent=True to avoid prompts
# Out:
# Loaded solar reference data from /Users/user/Documents/Jerome/GitHub/Abu_CoG/src/data/sol/AS09.dat
# No LIND2022 LTE file is found or "OVERWRITE" is True.
# LIND2022 LTE correction applied to raw data for Example
# No LIND2022 NLTE file is found or "OVERWRITE" is True.
# LIND2022 NLTE correction applied to raw data for Example

# %%
# Quick Preview of NLTE-corrected abundance together with Uncertainties (stored in data.nlte.elogeps)
# LTE abundance calculated from Lind et al. 2022 grids is stored in data.lte,
# while the my raw data is stored in data.liter
data.nlte.logeps
# Out:
#      Na    Mg    Al
# 0  6.08   NaN  6.38
# 1  5.80   NaN  6.23
# 2  3.89  5.58  4.05
# 3  3.38  5.30  3.66
# 4  3.43  5.32  3.86
